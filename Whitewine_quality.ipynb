# %%
 
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import seaborn as sns 
# %matplotlib inline 

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Loding dataset

# %%
#df_red=pd.read_csv(r'D:\DAT158\MachineLearningProject\Dat158Project\DataSet\winequality-red.csv')
#data=pd.read_csv(r'D:\DAT158\MachineLearningProject\Dat158Project\DataSet\winequality-white.csv',sep=';')

# Bruk hele filbanen for å være sikker på at filen blir funnet
data = pd.read_csv('/Users/moussaelrahmoun/Desktop/ML_Project/DataSet/winequality-white.csv', sep=';')
#data = pd.read_csv('/Users/moussaelrahmoun/Documents/GitHub/Dat158Project/DataSet/winequality-white.csv', sep=';')

#df_names=pd.read_csv(r'D:\DAT158\MachineLearningProject\Dat158Project\DataSet\winequality.names')

print(data)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# Exploring dataset

# %%
data.head(30)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# ...

# %%
data.shape
# Out:
# (4898, 12)

# %% [markdown]
#  our data consists of 4898 rows, 12 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# no missing vaalues according to info() function,

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
plt.figure(figsize=(14,8))
sns.histplot(data.quality,kde=True)
plt.xlabel('wineQuality')
plt.ylabel('count')
plt.title('winequalitiy distribution ')
plt.show()

# %%
data.hist(figsize=(14,8),bins=20)
plt.show()

# %% [markdown]
# "Most wines are rated 5-6, with fewer high or low ratings."

# %% [markdown]
# Let see what is the corelation between features and the quality

# %%
# plt.figure(figsize=(20, 17))
# matrix = np.triu(data.corr())
# sns.heatmap(data.corr(), annot=True,
#             linewidth=.8, mask=matrix, cmap="rocket")

# %% [markdown]
# Feature scaling the data

# %% [markdown]
# encoding

# %% [markdown]
# CHECKING THE VALUES VALUE SET OF  QUALITY

# %%
data['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %% [markdown]
# so the quality is between 3 and 9 According to Kaggle values below 6 rated as not good and 7 and abv is good

# %%
data['godquality']=[1 if x>=7 else 0 for x in data['quality']]
data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# ...

# %%
X=data.drop(['quality', 'godquality'],axis=1)
y=data['godquality']

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: godquality, dtype: int64

# %% [markdown]
# First splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=42)

# %% [markdown]
# evaluation

# %%
Model_res=pd.DataFrame(columns=['Model','Score'])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf_model=RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
Model_res.loc[len(Model_res)]=['RandomForestClassification',accuracy_score(y_test,y_pred)]
Model_res
# Out:
#                         Model     Score
# 0  RandomForestClassification  0.885714

# %%
from sklearn.linear_model import LogisticRegression 
lr_model=LogisticRegression()
lr_model.fit(X_train,y_train) 
y_pred_lr=lr_model.predict(X_test)

Model_res.loc[len(Model_res)]=['LogisticRegression',accuracy_score(y_test,y_pred_lr)]
Model_res
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                         Model     Score
# 0  RandomForestClassification  0.885714
# 1          LogisticRegression  0.790476

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=2)
model.fit(X_train,y_train)
y_pred_KN=model.predict(X_test)
from sklearn.metrics import accuracy_score
Model_res.loc[len(Model_res)]=['KNeighborsClassifier',accuracy_score(y_test,y_pred_KN)]
Model_res
# Out:
#                         Model     Score
# 0  RandomForestClassification  0.885714
# 1          LogisticRegression  0.790476
# 2        KNeighborsClassifier  0.810884

# %%
import xgboost as xgb
model=xgb.XGBClassifier(rando_state=42)
model.fit(X_train,y_train)
y_pered_x=model.predict(X_test)
Model_res.loc[len(Model_res)]=['XGBClassifier',accuracy_score(y_test,y_pered_x)]
Model_res
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [21:36:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "rando_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#                         Model     Score
# 0  RandomForestClassification  0.885714
# 1          LogisticRegression  0.790476
# 2        KNeighborsClassifier  0.810884
# 3               XGBClassifier  0.873469

# %% [markdown]
# as are nooticed the Random Foret has the highst accuracy than the XGBClassifier

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
colors = sns.color_palette("viridis", n_colors=len(Model_res['Model']))

sns.barplot(x=Model_res['Model'], y=Model_res['Score'],palette=colors)
plt.show()

# %% [markdown]
# SAVING THE BEST MODEL WE GOT RANDOMFOREST

# %%
import pickle

# %%
fileName='WienQuality_prediction.sav'   # saving my best model on this file 
pickle.dump(rf_model, open(fileName,'wb'))  #w for write, b for binary
